# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniilAszn/Python_course/blob/main/Python_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Условие 8.PNG](data:image/png;base64,...)

# %%
# cringe solution

def main(s):
    s = s.replace('\n', '')
    s = s.replace('|[[', '')
    s = s.replace('[[', '')
    s = s.replace(']], |', '')
    s = s.replace(']]', '')
    s = s.replace('=:', '-')
    s = s.replace(' - ', '-')
    s = s.replace('define ', '|')
    s = s.replace(',', '')
    s = s.replace(' ', '')
    s = s.replace('|', ' ')
    s = s.replace(' ', '', 1)
    s = s.split()
    # for i in range(len(s)):
    #     s[i] = s[i].split('-')
    # arr = []
    # for i in range(len(s)):
    #     arr_cur = (s[i][1], s[i][0])
    #     arr.append(arr_cur)
    k = len(s)
    for i in range(len(s)):
        s[i] = s[i].split('-')
    arr = []
    if k == 2:
        arr.append((s[0][1], s[0][0]))
        arr.append((s[1][1], s[1][0]))
    elif k == 3:
        arr.append((s[0][1], s[0][0]))
        arr.append((s[1][1], s[1][0]))
        arr.append((s[2][1], s[2][0]))
    elif k == 4:
        arr.append((s[0][1], s[0][0]))
        arr.append((s[1][1], s[1][0]))
        arr.append((s[2][1], s[2][0]))
        arr.append((s[3][1], s[3][0]))
    elif k == 5:
        arr.append((s[0][1], s[0][0]))
        arr.append((s[1][1], s[1][0]))
        arr.append((s[2][1], s[2][0]))
        arr.append((s[3][1], s[3][0]))
        arr.append((s[4][1], s[4][0]))
    return arr


s = '| [[ define esarri =: onarer ]], [[define onisqu_271 =: bexeed_593]],\n[[ define azasoso=:xeonan_301 ]], [[ define eratso_256 =: aninin_92\n]], |'
s = '|[[ define anza_435 =: atrela]],[[define onxera_701 =:orla_961 ]], |'
print(main(s))
